# %%
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
import kagglehub

handle = 'doanduchieu/paper'
local_dataset_dir = '/home/doanduchieu001/GitHub/ViT-MARL'

# Create a new dataset
kagglehub.dataset_upload(handle, local_dataset_dir)

# You can then create a new version of this dataset and include version notes.
kagglehub.dataset_upload(handle, local_dataset_dir, version_notes='improved data')

# You can also specify a list of patterns for files/dirs to ignore.
# These patterns are combined with 'kagglehub.datasets.DEFAULT_IGNORE_PATTERNS'
# to determine which files and directories to exclude. 
# To ignore entire directories, include a trailing slash (/) in the pattern.
kagglehub.dataset_upload(handle, local_dataset_dir, ignore_patterns=["original/", "*.tmp"])
# Out:
# Uploading Dataset https://kaggle.com/datasets/doanduchieu/paper ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file /tmp/tmpntteb2lw/archive.zip
# Uploading:  70%|██████▉   | 108M/155M [12:34<3:11:09, 4.11kB/s] Bad pipe message: %s [b'"Chromium";v="148", "Google Chrome";v="148", "Not/A)Brand']
# Uploading:  70%|██████▉   | 108M/155M [12:35<1:14:07, 10.6kB/s]Bad pipe message: %s [b'ol: max-age=0\r\nsec-ch-ua: "Chromium";v="148", "Google Chrome";v="148", "Not/A)Brand";v="99"\r\nsec-ch-ua-mobile: ?0\r\n']
# Uploading:  70%|██████▉   | 108M/155M [12:36<56:29, 13.9kB/s]  Bad pipe message: %s [b'c-ch-ua-platform: "Windows"\r\nUpgrade-Insecure-Requests: 1\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) A', b'leWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36\r\nAccept: text/html,application/xhtml+xml,app']
# Bad pipe message: %s [b'cation/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nSec-Fet', b'-Site: none\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-User: ?1\r\nSec-Fetch-Dest: document\r\nAccept-Encodi']
# Uploading:  70%|██████▉   | 108M/155M [12:37<34:36, 22.7kB/s]Bad pipe message: %s [b'ol: max-age=0\r\nsec-ch-ua: "Chromium";v="148", "Google Chrome";v="148", "Not/A)Brand";v="99"\r\nsec-ch-ua-mobile: ?0\r\n']
# Bad pipe message: %s [b'c-ch-ua-platform: "Windows"\r\nUpgrade-Insecure-Requests: 1\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) A', b'leWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36\r\nAccept: text/html,application/xhtml+xml,app']
# Bad pipe message: %s [b'cation/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nSec-Fet', b'-Site: none\r\nSec-Fetch-Mode: navigate\r\nSec-Fetch-User: ?1\r\nSec-Fetch-Dest: document\r\nAccept-Encodi']
# Uploading:  77%|███████▋  | 119M/155M [14:01<00:51, 696kB/s]
# Network issue: HTTPSConnectionPool(host='www.googleapis.com', port=443): Max retries exceeded with url: /upload/storage/v1/b/kaggle-data-sets/o?uploadType=resumable&upload_id=AAVLpEh4OYwsC3E4NikZpyVgvf481ALPtlgV-3keZQ_7box4mvv15K9s-EnC3zELi30LC5vAKGAMDRR3c3N7QyjTKrUPWN2pYkXsUNlVK46k6FQ (Caused by SSLError(SSLError(5, '[SSL: UNEXPECTED_EOF_WHILE_READING] unexpected eof while reading (_ssl.c:2580)'))), retrying in 1 seconds...
# Uploading: 100%|██████████| 155M/155M [16:21<00:00, 158kB/s]
# Upload successful: /tmp/tmpntteb2lw/archive.zip (148MB)
# Your dataset has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/doanduchieu/paper
# Uploading Dataset https://kaggle.com/datasets/doanduchieu/paper ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file /tmp/tmpmu_rfvag/archive.zip
# Uploading: 100%|██████████| 155M/155M [04:05<00:00, 631kB/s]
# Upload successful: /tmp/tmpmu_rfvag/archive.zip (148MB)
# Your dataset has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/doanduchieu/paper
# Uploading Dataset https://kaggle.com/datasets/doanduchieu/paper ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file /tmp/tmp57c3_9yt/archive.zip
# Uploading: 100%|██████████| 155M/155M [02:22<00:00, 1.09MB/s]
# Upload successful: /tmp/tmp57c3_9yt/archive.zip (148MB)
# Your dataset has been created.
# Files are being processed...
# See at: https://kaggle.com/datasets/doanduchieu/paper
